# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('STD Cases.csv')

# %%
df.head()
# Out:
#    index    Disease  Disease Code    State    Year Gender          Age  \
# 0      0  Chlamydia         274.0  Alabama  1996.0   Male   0-14 years
# 1      1  Chlamydia         274.0  Alabama  1996.0   Male  15-19 years
# 2      2  Chlamydia         274.0  Alabama  1996.0   Male  20-24 years
# 3      3  Chlamydia         274.0  Alabama  1996.0   Male  25-29 years
# 4      4  Chlamydia         274.0  Alabama  1996.0   Male  30-34 years
#
#   Age Code  STD Cases  Population  Rate per 100K
# 0     0-14       25.0    468394.0           5.34
# 1    15-19      164.0    165920.0          98.84
# 2    20-24      193.0    152848.0         126.27
# 3    25-29       88.0    152778.0          57.60
# 4    30-34       55.0    155850.0          35.29

# %%
df.tail()
# Out:
#        index Disease  Disease Code State  Year Gender  Age Age Code  \
# 42675  42675     NaN           NaN   NaN   NaN    NaN  NaN      NaN
# 42676  42676     NaN           NaN   NaN   NaN    NaN  NaN      NaN
# 42677  42677     NaN           NaN   NaN   NaN    NaN  NaN      NaN
# 42678  42678     NaN           NaN   NaN   NaN    NaN  NaN      NaN
# 42679  42679     NaN           NaN   NaN   NaN    NaN  NaN      NaN
#
#        STD Cases  Population  Rate per 100K
# 42675        NaN         NaN            NaN
# 42676        NaN         NaN            NaN
# 42677        NaN         NaN            NaN
# 42678        NaN         NaN            NaN
# 42679        NaN         NaN            NaN

# %%
df.describe()
# Out:
#               index  Disease Code          Year     STD Cases    Population  \
# count  42680.000000  42530.000000  42530.000000  42530.000000  3.548300e+04
# mean   21339.500000    283.795533   2005.240607    603.133647  4.389794e+05
# std    12320.799081     13.723063      5.431696   1973.091099  7.605588e+05
# min        0.000000    274.000000   1996.000000      1.000000  1.293700e+04
# 25%    10669.750000    274.000000   2001.000000      8.000000  9.418100e+04
# 50%    21339.500000    280.000000   2005.000000     59.000000  1.966280e+05
# 75%    32009.250000    280.000000   2010.000000    380.000000  4.322250e+05
# max    42679.000000    310.000000   2014.000000  46885.000000  8.880836e+06
#
#        Rate per 100K
# count   35483.000000
# mean      325.661860
# std       697.545461
# min         0.020000
# 25%         6.950000
# 50%        52.890000
# 75%       302.955000
# max      9078.950000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42680 entries, 0 to 42679
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          42680 non-null  int64
#  1   Disease        42530 non-null  object
#  2   Disease Code   42530 non-null  float64
#  3   State          42530 non-null  object
#  4   Year           42530 non-null  float64
#  5   Gender         42530 non-null  object
#  6   Age            42530 non-null  object
#  7   Age Code       42530 non-null  object
#  8   STD Cases      42530 non-null  float64
#  9   Population     35483 non-null  float64
#  10  Rate per 100K  35483 non-null  float64
# dtypes: float64(5), int64(1), object(5)
# memory usage: 3.6+ MB

# %%
df.isnull().sum()
# Out:
# index               0
# Disease           150
# Disease Code      150
# State             150
# Year              150
# Gender            150
# Age               150
# Age Code          150
# STD Cases         150
# Population       7197
# Rate per 100K    7197
# dtype: int64

# %%
# Fill missing values
df['Gender'].fillna(df['Gender'].mode()[0], inplace=True)  
df['Age'].fillna(df['Age'].mode()[0], inplace=True)          
df['STD Cases'].fillna(df['STD Cases'].mean(), inplace=True)  
df['Disease'].fillna(df['Disease'].mode()[0], inplace=True)  
df['Disease Code'].fillna(df['Disease Code'].median(), inplace=True)         
df['Year'].fillna(df['Year'].mean(), inplace=True)
df['Population'].fillna(df['Population'].mean(), inplace=True)
df['Rate per 100K'].fillna(df['Rate per 100K'].mean(), inplace=True)
df['Age Code'].fillna(df['Age Code'].mode()[0], inplace=True) 
df['State'].fillna(df['State'].mode()[0], inplace=True)

# %%
df.isnull().sum()
# Out:
# index            0
# Disease          0
# Disease Code     0
# State            0
# Year             0
# Gender           0
# Age              0
# Age Code         0
# STD Cases        0
# Population       0
# Rate per 100K    0
# dtype: int64

# %%
# Histogram for Age
plt.figure(figsize=(8, 5))
plt.hist(df['Age'], bins=5, color='skyblue', edgecolor='black')
plt.title('Age Distribution', fontsize=14)
plt.xlabel('Age', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
# Gender distribution bar chart
gender_counts = df['Gender'].value_counts()
plt.figure(figsize=(8, 5))
plt.bar(gender_counts.index, gender_counts.values, color='skyblue', edgecolor='black')
plt.title('Gender Distribution', fontsize=14)
plt.xlabel('Gender', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
